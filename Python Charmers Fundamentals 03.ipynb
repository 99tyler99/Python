# %%
import pandas as pd

meteorites = pd.read_csv(r"C:\Users\TylerHa\Python\Data\Meteorite_Landings.csv")
meteorites
# Out:
#              name     id nametype              recclass  mass (g)   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4  107000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#                          year    reclat    reclong             GeoLocation
# ...

# %%
meteorites.name
# Out:
# 0            Aachen
# 1            Aarhus
# 2              Abee
# 3          Acapulco
# 4           Achiras
#             ...
# 45711    Zillah 002
# 45712        Zinder
# 45713          Zlin
# 45714     Zubkovsky
# 45715    Zulu Queen
# Name: name, Length: 45716, dtype: object

# %%
meteorites.columns
# Out:
# Index(['name', 'id', 'nametype', 'recclass', 'mass (g)', 'fall', 'year',
#        'reclat', 'reclong', 'GeoLocation'],
#       dtype='object')

# %%
meteorites.index
# Out:
# RangeIndex(start=0, stop=45716, step=1)

# %%
import requests

response = requests.get(
    'https://data.nasa.gov/resource/gh4g-9sfh.json',
    params={'$limit': 50_000}
)

if response.ok:
    payload = response.json()
else:
    print(f'Request was not successful and returned code: {response.status_code}.')
    payload = None

# %%
import pandas as pd

df = pd.DataFrame(payload)
df.head(3)
# Out:
#      name id nametype recclass    mass  fall                     year  \
# 0  Aachen  1    Valid       L5      21  Fell  1880-01-01T00:00:00.000
# 1  Aarhus  2    Valid       H6     720  Fell  1951-01-01T00:00:00.000
# 2    Abee  6    Valid      EH4  107000  Fell  1952-01-01T00:00:00.000
#
#       reclat      reclong                                        geolocation  \
# 0  50.775000     6.083330     {'latitude': '50.775', 'longitude': '6.08333'}
# 1  56.183330    10.233330  {'latitude': '56.18333', 'longitude': '10.23333'}
# 2  54.216670  -113.000000    {'latitude': '54.21667', 'longitude': '-113.0'}
#
#   :@computed_region_cbhk_fwbd :@computed_region_nnqa_25f4
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN

# %%
meteorites.shape
# Out:
# (45716, 10)

# %%
meteorites.dtypes
# Out:
# name            object
# id               int64
# nametype        object
# recclass        object
# mass (g)       float64
# fall            object
# year            object
# reclat         float64
# reclong        float64
# GeoLocation     object
# dtype: object

# %%
meteorites.tail()
# Out:
#              name     id nametype              recclass  mass (g)   fall  \
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#                          year    reclat    reclong             GeoLocation
# 45711  01/01/1990 12:00:00 AM  29.03700   17.01850       (29.037, 17.0185)
# 45712  01/01/1999 12:00:00 AM  13.78333    8.96667     (13.78333, 8.96667)
# 45713  01/01/1939 12:00:00 AM  49.25000   17.66667       (49.25, 17.66667)
# 45714  01/01/2003 12:00:00 AM  49.78917   41.50460     (49.78917, 41.5046)
# 45715  01/01/1976 12:00:00 AM  33.98333 -115.68333  (33.98333, -115.68333)

# %%
meteorites.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45716 entries, 0 to 45715
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         45716 non-null  object
#  1   id           45716 non-null  int64
#  2   nametype     45716 non-null  object
#  3   recclass     45716 non-null  object
#  4   mass (g)     45585 non-null  float64
#  5   fall         45716 non-null  object
#  6   year         45425 non-null  object
#  7   reclat       38401 non-null  float64
#  8   reclong      38401 non-null  float64
#  9   GeoLocation  38401 non-null  object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 3.5+ MB

# %%
# Create a DataFrame by reading in the 2019_Yellow_Taxi_Trip_Data.csv file. Examine the first 5 rows.
#import package_name
import pandas as pd

# read file to variable
dataframe = pd.read_csv(r"C:\Users\TylerHa\Python\Data\2019_Yellow_Taxi_Trip_Data.csv")

# print the first 5 rows
dataframe.head()
# Out:
#    vendorid     tpep_pickup_datetime    tpep_dropoff_datetime  \
# 0         2  2019-10-23T16:39:42.000  2019-10-23T17:14:10.000
# 1         1  2019-10-23T16:32:08.000  2019-10-23T16:45:26.000
# 2         2  2019-10-23T16:08:44.000  2019-10-23T16:21:11.000
# 3         2  2019-10-23T16:22:44.000  2019-10-23T16:43:26.000
# 4         2  2019-10-23T16:45:11.000  2019-10-23T16:58:49.000
#
#    passenger_count  trip_distance  ratecodeid store_and_fwd_flag  \
# 0                1           7.93           1                  N
# 1                1           2.00           1                  N
# 2                1           1.36           1                  N
# 3                1           1.00           1                  N
# 4                1           1.96           1                  N
#
#    pulocationid  dolocationid  payment_type  fare_amount  extra  mta_tax  \
# 0           138           170             1         29.5    1.0      0.5
# ...

# %%
# Find the dimensions (number of rows and number of columns) in the data.
dataframe.shape
# Out:
# (10000, 18)

# %%
meteorites.name
# Out:
# 0            Aachen
# 1            Aarhus
# 2              Abee
# 3          Acapulco
# 4           Achiras
#             ...
# 45711    Zillah 002
# 45712        Zinder
# 45713          Zlin
# 45714     Zubkovsky
# 45715    Zulu Queen
# Name: name, Length: 45716, dtype: object

# %%
meteorites[['name', 'mass (g)']]
# Out:
#              name  mass (g)
# 0          Aachen      21.0
# 1          Aarhus     720.0
# 2            Abee  107000.0
# 3        Acapulco    1914.0
# 4         Achiras     780.0
# ...           ...       ...
# 45711  Zillah 002     172.0
# 45712      Zinder      46.0
# 45713        Zlin       3.3
# 45714   Zubkovsky    2167.0
# 45715  Zulu Queen     200.0
#
# [45716 rows x 2 columns]

# %%
meteorites[100:104]
# Out:
#               name     id nametype       recclass  mass (g)  fall  \
# 100         Benton   5026    Valid            LL6    2840.0  Fell
# 101         Berduc  48975    Valid             L6     270.0  Fell
# 102         Béréba   5028    Valid  Eucrite-mmict   18000.0  Fell
# 103  Berlanguillas   5029    Valid             L6    1440.0  Fell
#
#                        year    reclat   reclong          GeoLocation
# 100  01/01/1949 12:00:00 AM  45.95000 -67.55000      (45.95, -67.55)
# 101  01/01/2008 12:00:00 AM -31.91000 -58.32833  (-31.91, -58.32833)
# 102  01/01/1924 12:00:00 AM  11.65000  -3.65000       (11.65, -3.65)
# 103  01/01/1811 12:00:00 AM  41.68333  -3.80000     (41.68333, -3.8)

# %%
meteorites.iloc[100:104, [0, 3, 4, 6]]
# Out:
#               name       recclass  mass (g)                    year
# 100         Benton            LL6    2840.0  01/01/1949 12:00:00 AM
# 101         Berduc             L6     270.0  01/01/2008 12:00:00 AM
# 102         Béréba  Eucrite-mmict   18000.0  01/01/1924 12:00:00 AM
# 103  Berlanguillas             L6    1440.0  01/01/1811 12:00:00 AM

# %%
meteorites.loc[100:104, 'mass (g)':'year']
# Out:
#      mass (g)  fall                    year
# 100    2840.0  Fell  01/01/1949 12:00:00 AM
# 101     270.0  Fell  01/01/2008 12:00:00 AM
# 102   18000.0  Fell  01/01/1924 12:00:00 AM
# 103    1440.0  Fell  01/01/1811 12:00:00 AM
# 104     960.0  Fell  01/01/2004 12:00:00 AM

# %%
(meteorites['mass (g)'] > 50) & (meteorites.fall == 'Found')
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 45711     True
# 45712    False
# 45713    False
# 45714     True
# 45715     True
# Length: 45716, dtype: bool

# %%
meteorites[(meteorites['mass (g)'] > 1e6) & (meteorites.fall == 'Fell')]
# Out:
#               name     id nametype    recclass    mass (g)  fall  \
# 29         Allende   2278    Valid         CV3   2000000.0  Fell
# 419          Jilin  12171    Valid          H5   4000000.0  Fell
# 506  Kunya-Urgench  12379    Valid          H5   1100000.0  Fell
# 707  Norton County  17922    Valid     Aubrite   1100000.0  Fell
# 920   Sikhote-Alin  23593    Valid  Iron, IIAB  23000000.0  Fell
#
#                        year    reclat    reclong             GeoLocation
# 29   01/01/1969 12:00:00 AM  26.96667 -105.31667  (26.96667, -105.31667)
# 419  01/01/1976 12:00:00 AM  44.05000  126.16667      (44.05, 126.16667)
# 506  01/01/1998 12:00:00 AM  42.25000   59.20000           (42.25, 59.2)
# 707  01/01/1948 12:00:00 AM  39.68333  -99.86667   (39.68333, -99.86667)
# 920  01/01/1947 12:00:00 AM  46.16000  134.65333      (46.16, 134.65333)

# %%
meteorites.query("`mass (g)` > 1e6 and fall == 'Fell'")
# Out:
#               name     id nametype    recclass    mass (g)  fall  \
# 29         Allende   2278    Valid         CV3   2000000.0  Fell
# 419          Jilin  12171    Valid          H5   4000000.0  Fell
# 506  Kunya-Urgench  12379    Valid          H5   1100000.0  Fell
# 707  Norton County  17922    Valid     Aubrite   1100000.0  Fell
# 920   Sikhote-Alin  23593    Valid  Iron, IIAB  23000000.0  Fell
#
#                        year    reclat    reclong             GeoLocation
# 29   01/01/1969 12:00:00 AM  26.96667 -105.31667  (26.96667, -105.31667)
# 419  01/01/1976 12:00:00 AM  44.05000  126.16667      (44.05, 126.16667)
# 506  01/01/1998 12:00:00 AM  42.25000   59.20000           (42.25, 59.2)
# 707  01/01/1948 12:00:00 AM  39.68333  -99.86667   (39.68333, -99.86667)
# 920  01/01/1947 12:00:00 AM  46.16000  134.65333      (46.16, 134.65333)

# %%
meteorites.query("`mass (g)` > 1e6 and fall == 'Found'")
# Out:
#                        name     id nametype           recclass    mass (g)  \
# 1567       Al Haggounia 001  44857    Valid            Aubrite   3000000.0
# 1637             Alkhamasin    475    Valid         Iron, IIAB   1200000.0
# 3455                Armanty   2335    Valid         Iron, IIIE  28000000.0
# 5016             Bacubirito   4919    Valid    Iron, ungrouped  22000000.0
# 5083                Bendegó   5015    Valid           Iron, IC   5360000.0
# 5126                Bitburg   5062    Valid  Iron, IAB complex   1500000.0
# 5201                Brenham   5136    Valid  Pallasite, PMG-an   4300000.0
# 5363             Campinorte  52093    Valid    Iron, ungrouped   2000000.0
# 5365        Campo del Cielo   5247    Valid       Iron, IAB-MG  50000000.0
# 5370          Canyon Diablo   5257    Valid       Iron, IAB-MG  30000000.0
# 5373              Cape York   5262    Valid        Iron, IIIAB  58200000.0
# ...

# %%
meteorites.query("year" < 01/01/1000)
# Out:
#   Cell In[23], line 1
#     meteorites.query("year" < 01/01/1000)
#                               ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %%
meteorites.query("year" < 1/01/1000)
# Out:
#   Cell In[20], line 1
#     meteorites.query("year" < 1/01/1000)
#                                 ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %%
meteorites.query("year" < 1/1/1000)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 meteorites.query("year" < 1/1/1000)
#
# TypeError: '<' not supported between instances of 'str' and 'float'

# %%
meteorites['year'] = pd.to_datetime(meteorites['year'], format='%d/%m/%Y %H:%M:%S %p')
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# File strptime.pyx:460, in pandas._libs.tslibs.strptime.array_strptime()
#
# OverflowError: Overflow occurred in npy_datetimestruct_to_datetime
#
# The above exception was the direct cause of the following exception:
#
# OutOfBoundsDatetime                       Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 meteorites['year'] = pd.to_datetime(meteorites['year'], format='%d/%m/%Y %H:%M:%S %p')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1063, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1061             result = arg.tz_localize("utc")
#    1062 elif isinstance(arg, ABCSeries):
# -> 1063     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1064     if not cache_array.empty:
# ...

# %%
from datetime import datetime as dt
meteorites['year'] = pd.to_datetime(meteorites['year'])
# Out:
# C:\Users\TylerHa\AppData\Local\Temp\ipykernel_2912\208736467.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   meteorites['year'] = pd.to_datetime(meteorites['year'])
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# File conversion.pyx:326, in pandas._libs.tslibs.conversion._TSObject.ensure_reso()
#
# File np_datetime.pyx:683, in pandas._libs.tslibs.np_datetime.convert_reso()
#
# OverflowError: result would overflow
#
# The above exception was the direct cause of the following exception:
#
# OutOfBoundsDatetime                       Traceback (most recent call last)
# Cell In[32], line 2
#       1 from datetime import datetime as dt
# ----> 2 meteorites['year'] = pd.to_datetime(meteorites['year'])
#
# ...

# %%
meteorites['year'] = pd.to_datetime((meteorites['year']), errors = 'coerce')
# Out:
# C:\Users\TylerHa\AppData\Local\Temp\ipykernel_2912\1532616419.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   meteorites['year'] = pd.to_datetime((meteorites['year']), errors = 'coerce')

# %%
meteorites.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45716 entries, 0 to 45715
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         45716 non-null  object
#  1   id           45716 non-null  int64
#  2   nametype     45716 non-null  object
#  3   recclass     45716 non-null  object
#  4   mass (g)     45585 non-null  float64
#  5   fall         45716 non-null  object
#  6   year         45404 non-null  datetime64[ns]
#  7   reclat       38401 non-null  float64
#  8   reclong      38401 non-null  float64
#  9   GeoLocation  38401 non-null  object
# dtypes: datetime64[ns](1), float64(3), int64(1), object(5)
# memory usage: 3.5+ MB

# %%
meteorites[(meteorites['year'] < '1800-01-01')]
# Out:
#                     name     id nametype           recclass   mass (g)   fall  \
# 12       Aire-sur-la-Lys    425    Valid            Unknown        NaN   Fell
# 20              Albareto    453    Valid              L/LL4     2000.0   Fell
# 75              Barbotan   4942    Valid                 H5     6400.0   Fell
# 76     Barcelona (stone)   4944    Valid                 OC        NaN   Fell
# 94           Benares (a)   5011    Valid                LL4     3700.0   Fell
# 120       Bjelaja Zerkov   5063    Valid                 H6     1850.0   Fell
# 172    Castel Berardenga   5292    Valid         Stone-uncl        NaN   Fell
# 271            Eichstädt   7775    Valid                 H5     3000.0   Fell
# 386            Hraschina  11916    Valid          Iron, IID    49000.0   Fell
# 471              Kharkov  12291    Valid                 L6     1500.0   Fell
# 556                 Lucé  14724    Valid                 L6     3500.0   Fell
# ...

# %%
meteorites.query("year < '1850-01-01' and year > '1800-01-01'")
# Out:
#                  name     id nametype      recclass  mass (g)   fall  \
# 7                Agen    392    Valid            H5   30000.0   Fell
# 14           Akbarpur    427    Valid            H4    1800.0   Fell
# 19              Alais    448    Valid           CI1    6000.0   Fell
# 23          Aldsworth    461    Valid           LL5     700.0   Fell
# 38             Angers   2301    Valid            L6       NaN   Fell
# ...               ...    ...      ...           ...       ...    ...
# 37670       Smithland  23650    Valid     Iron, IVA    5000.0  Found
# 37674      Smithville  23654    Valid  Iron, IAB-MG   70500.0  Found
# 38248   Walker County  24204    Valid    Iron, IIAB   74800.0  Found
# 38306  Wichita County  24257    Valid  Iron, IAB-MG  145000.0  Found
# 45662      Yanhuitlan  30349    Valid     Iron, IVA  421000.0  Found
#
#             year    reclat   reclong            GeoLocation
# 7     1814-01-01  44.21667   0.61667    (44.21667, 0.61667)
# ...

# %%
meteorites.fall.value_counts(normalize=True)
# Out:
# fall
# Found    0.975785
# Fell     0.024215
# Name: proportion, dtype: float64

# %%
meteorites['mass (g)'].mean()
# Out:
# 13278.078548601512

# %%
meteorites['mass (g)'].quantile([0.01, 0.05, 0.5, 0.95, 0.99])
# Out:
# 0.01        0.44
# 0.05        1.10
# 0.50       32.60
# 0.95     4000.00
# 0.99    50600.00
# Name: mass (g), dtype: float64

# %%
meteorites['mass (g)'].median()
# Out:
# 32.6

# %%
meteorites['mass (g)'].max()
# Out:
# 60000000.0

# %%
meteorites.loc[meteorites['mass (g)'].idxmax()]
# Out:
# name                             Hoba
# id                              11890
# nametype                        Valid
# recclass                    Iron, IVB
# mass (g)                   60000000.0
# fall                            Found
# year           01/01/1920 12:00:00 AM
# reclat                      -19.58333
# reclong                      17.91667
# GeoLocation     (-19.58333, 17.91667)
# Name: 16392, dtype: object

# %%
meteorites.recclass.nunique()
print('hi')
# Out:
# hi

# %%
meteorites.recclass.unique()[:14]
# Out:
# array(['L5', 'H6', 'EH4', 'Acapulcoite', 'L6', 'LL3-6', 'H5', 'L',
#        'Diogenite-pm', 'Unknown', 'H4', 'H', 'Iron, IVA', 'CR2-an'],
#       dtype=object)

# %%
meteorites.describe(include='all')
# Out:
#           name            id nametype recclass      mass (g)   fall  \
# count    45716  45716.000000    45716    45716  4.558500e+04  45716
# unique   45716           NaN        2      466           NaN      2
# top     Aachen           NaN    Valid       L6           NaN  Found
# freq         1           NaN    45641     8285           NaN  44609
# mean       NaN  26889.735104      NaN      NaN  1.327808e+04    NaN
# std        NaN  16860.683030      NaN      NaN  5.749889e+05    NaN
# min        NaN      1.000000      NaN      NaN  0.000000e+00    NaN
# 25%        NaN  12688.750000      NaN      NaN  7.200000e+00    NaN
# 50%        NaN  24261.500000      NaN      NaN  3.260000e+01    NaN
# 75%        NaN  40656.750000      NaN      NaN  2.026000e+02    NaN
# max        NaN  57458.000000      NaN      NaN  6.000000e+07    NaN
#
#                           year        reclat       reclong GeoLocation
# count                    45425  38401.000000  38401.000000       38401
# ...
